# %%
import pandas as pd
import numpy as np

# %%
record=pd.read_excel("car price p.xlsx")
record
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
record['fueltype']= le.fit_transform(record['fueltype'])
  
record['fueltype'].unique()
# Out:
# array([1, 0])

# %%
record['aspiration']= le.fit_transform(record['aspiration'])
  
record['aspiration'].unique()
# Out:
# array([0, 1])

# %%
record['doornumber']= le.fit_transform(record['doornumber'])
  
record['doornumber'].unique()
# Out:
# array([1, 0])

# %%
record['carbody']= le.fit_transform(record['carbody'])
  
record['carbody'].unique()
# Out:
# array([0, 2, 3, 4, 1])

# %%
record['enginelocation']= le.fit_transform(record['enginelocation'])
  
record['enginelocation'].unique()
# Out:
# array([0, 1])

# %%
record['drivewheel']= le.fit_transform(record['drivewheel'])
  
record['drivewheel'].unique()
# Out:
# array([2, 1, 0])

# %%
record['enginetype']= le.fit_transform(record['enginetype'])
  
record['enginetype'].unique()
# Out:
# array([0, 5, 3, 2, 6, 4, 1])

# %%
record['cylindernumber']= le.fit_transform(record['cylindernumber'])
  
record['cylindernumber'].unique()
# Out:
# array([2, 3, 1, 4, 5, 6, 0])

# %%
record['fuelsystem']= le.fit_transform(record['fuelsystem'])
record['fuelsystem'].unique()
# Out:
# array([5, 1, 4, 0, 7, 2, 3, 6])

# %%
record.head()
# Out:
#    symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0          3         1           0           1        0           2
# 1          3         1           0           1        0           2
# 2          1         1           0           1        2           2
# 3          2         1           0           0        3           1
# 4          2         1           0           0        3           0
#
#    enginelocation  wheelbase  carlength  carwidth  ...  enginesize  \
# 0               0       88.6      168.8      64.1  ...         130
# 1               0       88.6      168.8      64.1  ...         130
# 2               0       94.5      171.2      65.5  ...         152
# 3               0       99.8      176.6      66.2  ...         109
# 4               0       99.4      176.6      66.4  ...         136
#
#    fuelsystem  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# 0           5       3.47    2.68               9.0         111     5000
# ...

# %%
record.drop(['CarName','car_ID'],axis=1,inplace=True)

# %%
record.head()
# Out:
#    symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0          3         1           0           1        0           2
# 1          3         1           0           1        0           2
# 2          1         1           0           1        2           2
# 3          2         1           0           0        3           1
# 4          2         1           0           0        3           0
#
#    enginelocation  wheelbase  carlength  carwidth  ...  enginesize  \
# 0               0       88.6      168.8      64.1  ...         130
# 1               0       88.6      168.8      64.1  ...         130
# 2               0       94.5      171.2      65.5  ...         152
# 3               0       99.8      176.6      66.2  ...         109
# 4               0       99.4      176.6      66.4  ...         136
#
#    fuelsystem boreratio stroke  compressionratio horsepower  peakrpm  citympg  \
# ...

# %%
record.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
record.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
import dtale
import seaborn as sns

# %%
record=pd.read_excel("car price p.xlsx")
dtale.show(record, ignore_duplicate=True)
# Out:
# 2021-08-11 22:26:22,190 - INFO     - NumExpr defaulting to 4 threads.
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-EMML5SK:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\hp\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\hp\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\hp\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\hp\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
# ...

# %%
# Model Building
from sklearn.model_selection import train_test_split
X = record.drop(columns='price')
y = record['price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# Creating Random Forest Model
from sklearn.ensemble import RandomForestRegressor
Regressor= RandomForestRegressor(n_estimators=20)
Regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=20)

# %%
X.shape
# Out:
# (205, 23)

# %%
y.shape
# Out:
# (205,)

# %%
np.shape
np.reshape(-1,1)
# Out:
# array([-1])

# %%
y_pred=Regressor.predict(X_train)
y_pred
# Out:
# array([16698.30835   , 34363.4       , 14441.5       , 11287.35      ,
#         7582.7       ,  7122.83666667, 14444.75      , 12969.83333333,
#         8673.75      , 21912.95835   ,  7164.25      ,  7954.05      ,
#         9698.65833333, 17088.7       , 18441.85      , 10515.86666667,
#        17766.35      ,  9822.05      ,  6321.75333333,  6148.7       ,
#        14749.5       ,  9972.9       ,  9228.54166667, 12260.        ,
#        14234.        ,  8364.05      ,  6071.5       ,  9870.15      ,
#         7785.5       ,  7154.85      ,  7989.8       ,  6011.55      ,
#         7288.8       ,  7283.55      , 16597.5       ,  7469.        ,
#        12894.95      ,  8214.2       , 15242.75      , 17309.5       ,
#        20846.45      ,  8177.1       , 14933.75      ,  8383.6       ,
#        33716.75      , 12742.95      , 13638.25      , 18939.4       ,
#         8399.9       ,  9228.54166667, 16442.85      ,  9698.65833333,
# ...

# %%
Regressor.score(X_test, y_test)
# Out:
# 0.898451569176056
